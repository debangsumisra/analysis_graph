# %%
# Write a code to find the degree of each vertex, and store it in a dictionary. Sort the keys of the dictionary by the degree stored in the values.

import os
import pandas as pd

# Given directory path
storage_dir = r"D:\MFC PROJECT\cleaned data"

# Initialize the adjacency list (dictionary)
graph_connections = {}

# Loop over all files in the folder
for document in os.listdir(storage_dir):
    if document.endswith(".csv"):
        # Create the key name by replacing '.' with '_' and removing '.csv'
        node_id = document.replace('.', '_').rsplit('_csv', 1)[0]
        
        # Full file path
        doc_path = os.path.join(storage_dir, document)
        
        # Read the CSV file
        try:
            table = pd.read_csv(doc_path)
        except Exception as fault:
            print(f"Failed to open {document}: {fault}")
            continue
        
        # Make sure columns exist
        if not {'First Name', 'Last Name'}.issubset(table.columns):
            print(f"'First Name' or 'Last Name' column missing in {document}")
            continue

        # Initialize list to store combined names
        individuals = []

        # Process each row
        for line_idx, line in table.iterrows():
            fname = str(line.get('First Name', '')).strip()
            lname = str(line.get('Last Name', '')).strip()

            # Create full name based on availability
            if fname and lname:
                full_identity = f"{fname}_{lname}"
            elif fname:
                full_identity = fname
            elif lname:
                full_identity = lname
            else:
                continue

            individuals.append(full_identity)

        # Add to the adjacency list
        graph_connections[node_id] = individuals

# Done!
print("Successfully Created Graph Connections!")

# If you want to see part of the result
for node, connections in list(graph_connections.items())[:5]:  # show first 5 nodes
    print(f"{node}: {connections}")

# Optional: Save the adjacency list to a JSON file if needed
import json
export_path = r"D:\MFC PROJECT\adjacency_list.json"
with open(export_path, "w", encoding="utf-8") as handle:
    json.dump(graph_connections, handle, ensure_ascii=False, indent=4)

print(f"Graph connections exported to {export_path}")

# Sorting the nodes based on degree (length of connection list)
sorted_graph = {}
sort_order = sorted(graph_connections.items(), key=lambda ele: len(ele[1]), reverse=True)
for key_val, people in sort_order:
    sorted_graph[key_val] = people

# Done!
for vertex, group in sorted_graph.items():
    print(vertex, ":", len(group))
# Out:
# Successfully Created Graph Connections!
# Aaditya_Raj: ['Harsh Kumar_Singh', 'Saurabh_Singh', 'Anamika_Kumari', 'Hariom_Parmar', 'sukhe...⁰_🩺', 'Mani_Kumar', 'Himanshu_Srivastav', 'Mudasir_Ahmad', 'Ayush_Katiyar', 'Radhika_Pal', 'Punam_Mandal', 'Prakash_Behera', 'Nikita_Paikara', 'Mohammad_zaid', 'Rudraksh_Namdeo', 'Ankit_Kumar', 'Aakash_Kumar', 'Amrita_Yadav', 'Adityansh_Chand', 'Mohd shadab_Ansari', 'Rohit_Pingale', 'Amit_Diwakar', 'Siddharth_Sahani', 'Hrishikesh_dixit', 'Vishal_Bhardwaj', 'Mohit_Sharma', 'Divyanshu_Fartiyal', 'Ritik_Singh', 'Rudra Pratap Singh_Chauhan', 'abhinav_mishra', 'Vishal_Dhaniya', 'Amrita_Kumari', 'Chhaya_Pawar', 'Shivani_Parashwar', 'Nishant_Rasekar', 'Neha_Sawadkar', 'Abhishek_Tripathi', 'Nalini_Agarwal', 'Prince_Yadav', 'Abhishek_Kumar', 'Rani_Kumari', 'Nitin/Nimish_Rastogi', 'Nikhil Raj_Soni', 'Manvendra_Singh', 'Ranjan_Singh', 'Guman_Singh', 'Maneesh_Sakhwar', 'Challa Trivedh_Kumar', 'Mayank Singh_Tomar', 'Deependra_Shukla', 'Priyanshu_Yadav', 'Muskan_Yadav', 'Dilip_Vaishnav', 'Deepak_Kumar', 'CHANDAN_GIRI', 'Rakshita K_Biradar', 'Anuradha_Tiwari', 'Madhur_Mishra', 'Sahil_Kumar', 'Vishal_Yadav', 'Himanshu_kumar', 'Shivam_Tiwari', 'Ricardo_Baeza-Yates', 'Bikram_Ravidas', 'Abhinab_Roy', 'Sandeep_kumar', 'Divyansh_Agrawal', 'Bhagwan_singh', 'Amir_Khan', 'Shivam_Srivastava', 'Vidhi_Mishra', 'Rajkumar_Senapati', 'Ammar_Husain', 'Anoop_Kumar', 'Hemant_Meena', 'Aditya_Singh', 'Ajay_Kumar', 'Ankita_Pancholi', 'Arpit_Sahu', 'Ishan_.', 'Pradeep_Kumar', 'Kushal_Jain', 'Sahil_Kumar', 'Saurabh_Yadav', 'Bhagwati_Chouhan', 'Ritesh Kumar_Yadav', 'Anamika_Kumari', 'Yash_Yadav', 'Ravi_Mourya', 'Janu_Chaudhary', 'RAJESH_KUMAR', 'Chandan_Kumar', 'Shubham_Kumar', 'Afzal_Raza', 'Rayala_Abhilash', 'Shreyank_Sthavaramath', 'Yuvraj Singh_Bhati', 'Naman_Damami', 'Harsh_Chourasiya', 'Pooran_Singh', 'Satish_Mahto', 'Ranjeet_Yadav', 'Gaurav_Kumar', 'Mayank_Rai', 'Rijwith_Mamidi', 'Arpita_Tripathi', 'Ajit_Yadav', 'Gaurav_Tiwari', 'Sandhya_Kaushal', 'Nishant_Koundal', 'Garv_Rawal', 'Vinay Singh_Rawat', 'Rishaub_Kumar', 'Ishan Singh_Chadha', 'Shivang_Dubey', 'Vinay_Prajapati', 'Pranjal_Dubey', 'Chelsi_Saini', 'Ramesh_Kumar', 'Shekhar_Shrivas', 'Vaishnavi_MURALIDHAR', 'Saurabh_Bisht', 'Sarthak_Shukla', 'Shivam_Singh', 'Navneet_Patidar', 'Manoj_Kharkar', 'Manish_Chhaba', 'KARANPAL SINGH_RANAWAT', 'Louv_Krishna Upadhyay', 'Surya Prakash_vishwakarma', 'Aditya_Singh', 'Anmol_Kumar', 'RITESH_JHA', 'Nikhil_Yadav', 'Shadab_Raza', 'Swati_Kumari', 'Pankaj_Rishi', 'Himanshu_Kumar', 'Sajan_Kumar', 'Aslam_Khan', 'Mausam_Kumari', 'Aditya_agrahari', 'Amit_Singhal', 'Arpit_Tiwari', 'Priyanshu_Anand', 'Anshu_Kumar', 'Ayush_Yadav', 'Pankaj_Yadav', 'SANDEEP_KUMAR', 'Harsh_Rawat', 'Manish_Tiwari', 'Raja_Yadav', 'Bhaskar_Mahato', 'Priyam_Sahu', 'Ayush_Kumar', 'Rohit_Kahar', 'Ishika_Srivastava', 'Kuldeep_Saraswat', 'Ramendra_Kumar', 'SANJAY_V P', 'Mayank_Raj', 'MAHESH_MEENA', 'Aarti_Patil', 'Avinash_kumar', 'Nirmal_Mewada', 'Arun_Singh', 'Achal_Agrawal, PhD', 'Rohit_Kumar', 'Kirtan_Khichi', 'Preeti_Shukla', 'Rajeev_Yadav', 'Gaurav_Rathore', 'Anshul_Sharma', 'Ritik_Rajvanshi', 'Ajeet_Kumar', 'Nikhil_Verma', 'Ritik_Kumar', 'Kushal_Shah', 'Shashank_Kumar', 'Divyansh_Mishra', 'Ravi_Rajput', 'Shahid_Ansari', 'Byagari_Praveen Kumar', 'Arjun_Kadam', 'Saksham_Bharti', 'Pawan_Kushwah', 'Nagmani_Kumar', 'Rajat_Malviya', 'Shubham_Kang', 'Ajay_Jatav', 'Rajiv_Kumar', 'Vishal_Yadav', 'Sarthaksuman_Mishra', 'Pintu_Lohar, PhD', 'Neeraj_Parmar', 'Prince_Anand', 'Amit_Kumar', 'Mohd_Monis', 'Aakash_Deep', 'Jeet_Mukherjee', 'Joel_Moirangthem', 'Rahul_Kumar', 'Prakash_Marandi', 'Mallesh_Kamati', 'Satyam Kumar_Pandey', 'Manu_Kumar', 'Shivam_Kumar', 'Narayan_Jat', 'Yashwardhan Singh_Chundawat', 'Shivam_Shukla', 'Prabhat_Patidar', 'Aman_Singh', 'Ompal_Yadav', 'Surveer Singh_Rao', 'Aman_Verma', 'Yuvraj_Chirag', 'Monu_Rajpoot', 'Manoj_Dewda', 'Ashutosh_Kumar', 'Harisingh_Rajpoot', 'Dilip_Suthar', 'Lakhan_Rathore', 'Alok_Raj', 'Nikhil_Mehta', 'Nallamothu_Arun Kumar', 'Nikhil_Chaurasiya', 'Deepak_Mandal', 'Rohit_Mal ...
# Abhishek_Singh: ['tarang_pandey', 'Aarti_Patil', 'Lokesh_Prajapat (HR)', 'Prabhat_Kumar', 'Baikuntha_Nath Mangual', 'Shilpa_Gangthade', 'Raj_Kiran', 'Ram_Damare', 'Vineela_Deepti Naidu', 'Himanshi_Chauhan', 'abhinav_mishra', 'HASAN_SIDDIQUI', 'Shankho Subhra_Pal', 'Jayalakshmi_B G', 'Rijwith_Mamidi', 'Vivek_Kumar', 'Vinay_Gupta', 'Manish_Yadav', 'Mamta_Kashyap', 'Aslam_Khan', 'Ompal_Yadav', 'Vinay_Kumar', 'Piyush_Verma', 'Ayush_Kumar', 'RITESH_JHA', 'Punyadeep singh_Solanki', 'Anmol_Kumar', 'Dr.  Prosenjit_Gupta', 'Gurunath_Naduvin', 'Ravi_Rajput', 'nan_nan', 'Arpita_Maurya', 'Krishna Pad_Das', 'Shivang_Dubey', 'Guman_Singh', 'Hirak_Nath', 'Prerana_Rajnag', 'Ajeet_Kumar', 'Rinika_Banerjee', 'Mahtab_Alam', 'Abhishek_Verma', 'CHANDAN_GIRI', 'suneel_kushwaha', 'Yuvraj_Chirag', 'JAMAL_AKHTAR', 'Shilpa_Singhal', 'Ritesh Kumar_Yadav', 'Preeti_Shukla', 'Pintu_Lohar, PhD', 'Anand_Singh', 'Rohit_Kahar', 'Azim_Shaikh', 'Suyash_Yadav', 'kiran_kumar', 'Kotholla_Viswa teja', 'Nikhil_Chaurasiya', 'Ujjval_Baijal', 'Nirmal_Mewada', 'Ishant_Bhoyar', 'Neeraj_Parmar', 'Abhishek_Kumar', 'Ajay_Jatav', 'Bhaskar_Mahato', 'Ekta_Kumari', 'Gaurav_Rathore', 'Vivek_Singh', 'RAHUL_CHAUHAN', 'Mayank_Raj', 'Nidhi_Kumari', 'Manoj_Dewda', 'Ajit_Yadav', 'Himanshu Kanwar_Chundawat', 'Vishal_Bhardwaj', 'Vinay_Prajapati', 'Disha_Sahu', 'Nagmani_Kumar', 'Amit_Diwakar', 'Dilip_Suthar', 'nan_nan', 'Alok_Raj', 'Manish_Tiwari', 'Anand_Pandey', 'Debangsu_Misra', 'Prem_Kumar', 'SUDHIR_KUMAR', 'Mehtab_Alam', 'Prabhash_kumar manjhi', 'Atul_Patel', 'Mausam_Kumari', 'Bharat_Suthar', 'Priya_Saini', 'Anamika_Kumari', 'Ayush_Arora', 'Rakshita K_Biradar', 'Mohd shadab_Ansari', 'Gowtham_MN', 'Nikhil_Saini', 'Vishal_Kumar', 'nan_nan', 'Harshal_Soni', 'AKASH_KUMAR', 'Aaditya_Singh', 'Amit_Singhal', 'Rohit_Malviya', 'Ashish Kumar_Gupta', 'Amisha_yadav', 'Mahak_Tripathi(MBA)', 'Kushal_Shah', 'Achal_Agrawal, PhD', 'Vishal_Mishra', 'toukir_Alam', 'Priyanshu_Raj', 'Rajat_Shinde', 'Divyansh_Mishra', 'Trideep Bishal_Bhowmik', 'Krishna Rajput_Samaj Sevi', 'VIJAY_KUMAR 🇮🇳', 'Rahul_Panwar', 'Rahul Kumar_Verma', 'Swarnali_Saha', 'Kajol_Kashipuri', 'Nayak_Monali', 'Shivakumar_Lamani', 'Smriti_Vinay', 'Hemant_Jangde', 'Amit Kumar_Singh', 'Saurabh_Kumar', 'Sarthak_Shukla', 'Nikhil_Yadav', 'Ishan_Vasisth', 'SANDEEP_KUMAR', 'Divyansh_Porwal', 'AyesH_SuvankaR', 'SANJAY_V P', 'Sahil_Kumar', 'Suraj_Prajapati', 'Rajesh_Saha Biswastami 🇮🇳', 'Jogendra_Singh', 'Lalit_Kumar', 'Soumya_Gupta', 'Neetesh_Kumar 🇮🇳', 'Animesh_Awasthi', 'Azad_Babu', 'Saurabh_Yadav', 'Sachin_Maurya', 'Riya_Kumari', 'Narayan_Jat', 'Anshul_Sharma', 'Pallavi_Maurya', 'Nikhil Raj_Soni', 'Satyam Kumar_Pandey', 'Ajay_Kumar', 'Sneha_Rani', 'Ritik_Kumar', 'ANSHU__', 'Sahil_Kumar', 'Deepak_Kumar', 'Manvendra_Singh', 'Harsh_Rawat', 'Yashwardhan Singh_Chundawat', 'Rashmi_kumari', 'Anamika_Kumari', 'Narendra Singh_Chouhan', 'Suresh Singh_Panwar']
# Aditya_Singh: ['Satendra_Kumar', 'Aakash_Kumar', 'Maneesh_Sakhwar', 'Ricardo_Baeza-Yates', 'Mohd shadab_Ansari', 'Ankita_Vishwakarma', 'Anshika_Dubey', 'Chhaya_Pawar', 'Priyanshu_Dubey', 'Prakash_Behera', 'Arjita_Singh', 'Vaishali_Sinha', 'Muskan_Singh', 'Rajiv_Kumar', 'Aradhya_Sinha', 'Shankho Subhra_Pal', 'Garima_Tiwari', 'Shambhavi_Srivastava', 'Pragya_Sharma', 'Shagun_Singh', 'Priyanka_Gupta', '._PRIYANKA', 'Shalini_Priya', 'Anjali_Verma', 'Priyanshi_Agrawal', 'Anoop_Kumar', 'Anu_Yadav', 'Ritik_Singh', 'Ritesh Kumar_Yadav', 'Nirmal_Kumar', 'Dheerendra_Mishra', 'Hariom_Parmar', 'Abhishek_Tripathi', 'Afzal_Raza', 'Abhishek_Kumar', 'SHIPRA_SINGH', 'Rohit_Kumar', 'Yash_Yadav', 'Gaurav_Kumar', 'Ranjeet_Yadav', 'Ramendra_Kumar', 'Sandeep_kumar', 'ANUJ_GANGWAR', 'Bhavishya_Verma', 'Amir_Khan', 'Varun_Polapelly', 'Chelsi_Saini', 'Rishaub_Kumar', 'Roshan_Gupta', 'Rijwith_Mamidi', 'Ajit_Yadav', 'Kirtan_Khichi', 'Deepak_Kumar', 'Shadab_Raza', 'Narayan_Jat', 'Prem Shankar_Kushwaha', 'Nikhil_Mehta', 'Aakash_Deep', 'Mohd_Faisal', 'Kishor_Parmar - TechyKP', 'Raja_Yadav', 'MANISH_PAL', 'AMAN_Singh', 'Vikash_Kumar', 'Prabhat_Patidar', 'Aaditya_Raj', 'ram_vemula', 'Avinash_kumar', 'Sajan_Kumar', 'Mausam_Kumari', 'Aman_Verma', 'Ramraj_Nagar', 'Roli_Rathour', 'Anushka_Singh Lodhi', 'Prabhat_Kumar', 'Baikuntha_Nath Mangual', 'Rakhi_Barman', 'Aarti_Patil', 'Vivek_Kumar', 'Ashik_Muhammed.S', 'Vinay_Gupta', 'nan_nan', 'Ajay_Singh', 'Saurav_Dhakar', 'Anshu_Kumar', 'Pinky_Rana', 'Chandan_Patel', 'sukhe...⁰_🩺', 'Abhishek_Verma', 'Rajeev_Yadav', 'RAHUL_CHAUHAN', 'Chiranjeet_Biswas', 'JUHI_GUPTA', 'Ajinkya_Chandurkar', 'Dilip_Vaishnav', 'Arya_Meshram', 'Ram Bhanwar_Bhadiyar', 'Manish_Yadav', 'Mamta_Kashyap', 'Pushpendra_Uikey', 'Aslam_Khan', 'Pradeep_Kumar', 'Jyotika_Maurya', 'Saurabh_Bisht', 'Mayank Singh_Tomar', 'Pushplata_Kaithwar', 'Vivek_Singh', 'Gaurav_Tiwari', 'Vinay_Prajapati', 'Sandhya_Parmar', 'Shrishti_Agrawal', 'RITESH_JHA', 'Aditi_Srivastava', 'Aditya_agrahari', 'Jeet_Mukherjee', 'Lakhan_Rathore', 'Anand_Singh', 'Pooran_Singh', 'Sapna_Kumari', 'Aman_Adarsh', 'Nidhi_Kumari', 'Shekhar_Shrivas', 'Khushi_Maurya', 'Prince_Lidhoriya', 'Mayank_Pratap singh', 'Shubham_Kumar', 'Mahendra_Prajapati', 'Shilpi_Shaw', 'Anjila_Shreshth', 'Shahid_Ansari', 'Gaurav_Chaudhary', 'Pranjal_Dubey', 'Piyush_Maurya', 'Ashwin_Yadav', 'Vishal_Bhardwaj', 'Madhwendra_Shukla', 'Shubhi_Upadhyay', 'Bhagwati_Chouhan', 'Neeraj_Kumar', 'Vaishnavi_Nigam', 'Amit_Kumar', 'Rayala_Abhilash', 'Sunny_Kumar', 'Vidya_Bharti', 'Akash Singh_Rautela', 'Kritika_Singh', 'Yash_Chittora', 'Hemant_Meena', 'Nallamothu_Arun Kumar', 'Uppara Sai_Maithreyi', 'Ayush_Yadav', 'Akanksha_Kushwaha', 'Pragati_Chauhan', 'Pawan_Kushwah', 'Aman_Singh', 'Sarthaksuman_Mishra', 'Rahul_Kumar', 'Sandhya_Kaushal', 'Kuldeep_Saraswat', 'Vishal_Yadav', 'Surveer Singh_Rao', 'Swati_Kumari', 'Anuradha_Tiwari', 'Anmol_Kumar', 'Bharat_Suthar', 'Ranjan_Singh', 'Anushri_Mishra', 'Samina_Sultana', 'Divyanshi_Rathour', 'Rahul Kumar_Verma', 'Arpita_Tripathi', 'Neeraj_Parmar', 'Karthic_Elangovan', 'Rani_Kumari', 'Vinay_Kumar', 'Bhaskar_Mahato', 'Nitish kumar_Gautam', 'Satish_Mahto', 'Kajol_Kashipuri', 'Joel_Moirangthem', 'JAMAL_AKHTAR', 'Mohit_Sharma', 'Himanshu_Srivastav', 'Shivam_Shukla', 'Punyadeep singh_Solanki', 'Chandan_Kumar', 'Guman_Singh', 'Achal_Agrawal, PhD', 'Shilpa_Singhal', 'MAHESH_MEENA', 'nan_nan', 'Raushan_Kumar', 'Ayush_Kumar', 'Rohit_Kahar', 'Ayush_Parmar', 'Khushi_Narwariya', 'Nagmani_Kumar', 'Deepak_Mandal', 'Harsh_Mishra', 'Swarnali_Saha', 'Anand_Pandey', 'Prachi_Dhakad', 'Priyam_Tripathi', 'Byagari_Praveen Kumar', 'Prem_Kumar', 'Debangsu_Misra', 'Nikhil_Chaurasiya', 'Mohd_Monis', 'Himanshu_Kumar', 'Ishant_Bhoyar', 'Suresh Singh_Panwar', 'Pankaj_Rishi', 'Dilip_Suthar', 'Yuvraj_Chirag', 'Divyanshi_Sahu', 'Prerana_Rajnag', 'Mohd anas_siddiqui', 'Satyam Kumar_Pandey', 'Nirmal_Mewada', 'Sauhard_Kumar', 'Rohit_Malviya', 'Sneha_Shaw', 'Hiranya_Patil', 'Suyash_Yadav', 'Anshul_Sharma', 'Hirak_Nath', 'Gaurav_Ra ...
# Afzal_Raza: ['Shalini_Parmar', 'Sunil_Ingole', 'Vanshika_Das', 'Suraj Kumar_Sharma', 'Nishi_Choudhary', 'Arnab_Pradhan', 'Laxmidhar_Nayak', 'Aditi_Maurya', 'Aditya Pratap_Singh', 'Sufanpreet_Kaur', 'Adarsh_Tiwari', 'Pooja_Godara', 'Divye_Vaibhav', 'Harsh_Mishra', 'Mithilesh_Maurya', 'Aryan_Singhal', 'Pratibha_singh', 'NANDINI_TIWARI', 'Ashutosh Kumar_Singh', 'Shambhavi_Srivastava', 'Khushi_Singh', 'Nouran_Ahmed', 'Ashish_Pratap Chaudhary', 'Naman_Pathak', 'Pranjal_Khandelwal', 'Shreyansh_Rai', 'Yash_Singh', 'Vani_Verma', 'Akshi_......', 'Faisal_Hayat', 'Oliphiea_Bhanga', 'Laxmi_Prajapati (ラクシュミ )', 'Mrinal_Tripathi', 'Saeei_Suryawanshi', 'Prachii_Maurya', 'Abdul_Ahad', 'Shivangi_Duggal', 'Sparshi_Singh', 'Sajal_Vishwakarma', 'Gaurav_Kumar', 'Anitha_Chava', 'Ankit_Rai', 'Ayush_Yadav', 'Er JITENDRA_Singh', 'Prakhar_Srivastava', 'Avinash_Ugale', 'Er. Sejal_Singh', 'Nidhi_Yadav', 'Gaurav_Kumar', 'Himanshu_Srivastav', 'Akash_Kumar', 'Puneet_Mishra', 'Aditya_Singh', 'Roopam_Gupta', 'Rahul_Kumar', 'Akhil Kumar_Sharma', 'Vaibhaav_Tiwari', 'Mohammad Taha_Rizvi', 'Vidhi_Doshi', 'Raj_Maurya', 'Sunny_Mall', 'Prashant_Poddar', 'Hardik_Singh', 'Hemant kumar_sahu', 'Md_Ashraf', 'SHIVANGI_SINGH', 'Ankit_Prajapati', 'Tejeshwar_JNV', 'Dipanshi_Sharma', 'Krishna_Srivastava', 'Siddhant_Tripathi', 'Soumya_Singh', 'Abhishek_Verma', 'Neha_Dhangar', 'Aniket_Chaurasia', 'Silky_Gupta', 'Riddhima_Singh', 'Abhi_Singh', 'Vishal_Maurya', 'Mukesh_Singh', 'Abhay_Singh', 'Shantanu_Singh Verma', 'Krish_Rally', 'Muskaan_Verma', 'Aprajita_Sharma', 'Suhail_Ghazi', 'Arpit_Patel', 'Tushar_Sonker', 'Prince_Mishra', 'Satyam_Kumar', 'Sanchit_Dass', 'BARSHARANI_SAHU', 'Anchal_Shukla', 'Adamya_pathak', 'Nitish_Rai', 'Ashmit_Gautam', 'Akchat_Dubey', 'Akanksha_K', 'Mani_Kumar', 'Mehul_Gupta', 'Mohammed_Zakir Naseem', 'Deepak_Saini', 'Priyanshu_Singh', 'Aakash_Verma', 'Harshit_Mishra', 'Siddharth_Pant', 'Sachindra shekhar_Pandey', 'Ashish_Pathak', 'Alok_Dhar Dubey', 'Mukul_Kumar Ojha', 'Kushagra_Gupta', 'Vaishali_Tyagi', 'Archita_Saraswati', 'Aleyna_Çetin', 'Shamail_Khan', 'SWETA_MISHRA', 'Shubhra_Tiwari', 'HariOm_Dwivedi', 'Shweta_Pandey', 'Jigyasa_Gupta', 'Karan_Gupta', 'Ananya_Mondal', 'Sukarnya_Datta', 'Neha_Shukla', 'Anirudh_Sharma', 'Ayush Kumar_Singh', 'Utkarsh_Kumar', 'Muzammil_Ahsan', 'Shaheen_Khatoon', 'Ashray Deep_Bajpai', 'Chisa_G Momin', 'Ananya_Singh', 'Mohd Faiz_Khan', 'Shreya_Gupta', 'Vaishnavi_Gupta', 'Abhishek_Yadav', 'Amolly_Choudhary', 'Abhishek_Gautam', 'Yash_Mittal', 'Samaira_Katoch', 'Aryan_Patel', 'Shilpa_Singhal', 'Akash_Verma', 'ARYAN_Athreya', 'Yash_Verma', 'Kiran_Chauhan', 'Sneha_Singh', 'Shubham_Jain', 'Karthic_Elangovan', 'Nayak_Monali', 'Shalini_Rao', 'Vindhaya_Gautam', 'Ujjwal Pratap_Singh', 'Sumit_Giri', 'Ritik kumar_Pandey', 'Raima_Jash', 'Madhuri_Rajpoot', 'Nayeem Ul_Rashid', 'Nandan_kumar', 'Saloni_Goel', 'Akash Singh_Rautela', 'Devansh_Tiwari', 'Rabhya_Sharma', 'PAWANI_SHARMA', 'Gita_kumari', 'Saumya_Chandra', 'Tanisha_Bhatt', 'ESHANI RAJ_VERMA', 'Richa_Jaishwal', 'Suprity_Rani', 'Radhikaa_Jaiswal', 'Shivendra Kumar_Sonkar', 'Abhishek Gowda_A L', 'Himanshu_Srivastava', 'Gauraangi_Praakash', 'Tanu Shree_Dutt', 'Sakshi_Verma', 'Puja_Patel', 'Deevyansh_Khadria', 'Krishna_Singha', 'Aryan_Shukla', 'Meer_Sohaib', 'Madhwendra_Shukla', 'Siddhi_Singh', 'Priya_Pahuja', 'Chandresh_Munjapara', 'Sukhman_Saini', 'Sanket_panigrahi', 'Diti_Verma', 'Divya_Chandra Srivastava', 'Nirjara_Jain', 'Mayanka_.', 'OMKAR_NIMBALKAR', 'Sweta_Priya', 'Jilledimudi_Tejeswari', 'Shreya_Singh', 'Muskan_Singh', 'Soumya_Bhakuni', 'Kanak_Patil', 'Divyanshi_Bisht', 'Kushagra_Patel', 'Samridh_Palleda', 'Padmasri_Chintada', 'Aastha_Thakur', 'Rahul Kumar_Verma', 'Mohd Asad_Shoyeb', 'Sameer_Lucky', 'Ravi_Yadav', 'Suyash_Kumar', 'Aarya_Joshi', 'Shaily_Singh', 'Kapil_Raghav', 'Sandip_Kumar', 'Bhagwan_singh', 'Sachin_Maurya', 'Kumar_Shanu Sinha', 'Sakshi_.', 'Ashwani_Pandey', 'Sonam_Chuskit', 'Prasanna_Chavhan', 'RAJESH_KUMAR', 'Ayush_Kumar', 'Prakash_Behera', 'SATYAM_UPADHYAY', ' ...
# Ajay Jatav Connections-1: ['Shalini_Singh', 'Whitehattoolbox_Jobs', 'SomitraSR from_Timidlly 馃殌', 'Sandip_Kumar', 'Surbhi_Kumari', 'Arya Vrat_Yadav', 'Mahi_Chauhan', 'Krishn_Singh', 'Mohammad_zaid', 'Krishna_Chaurasiya', 'Aakash_Kumar', 'Vikash_Bairwa', 'Vikas_Goswami', 'Bhawna_Sharma', 'Yash_Mittal', 'Mehul_Gupta', 'ASHISH_SINGH', 'Om_Omer', 'Aditya_Chaudhary', 'Khushi_Rana', 'Ritesh Kumar_Gorai', 'Sanskriti_Srivastava', 'Youth And Child Development_Association', 'Yogendra_Yadav', 'Abhilash_Yadav', 'Satendra_Kumar', 'Ankush_shukla', 'Nainshi_Mishra', 'Sunny Singh_Jadon', 'DIVYA_YADAV', 'Abhay_Pratap', 'Sameer_Mishra', 'Harshit_Verma', 'Raja_Yadav', 'DESHPREMI_JATAV', 'Shivam_Srivastava', 'AMAN_KANOJIYA', 'Sankalp_shrivastava', 'Ashutosh_Singh', 'Sabiya_Ansari', 'Aniket_Singh', 'Shubhi_Singh', 'Anupama_Maurya', 'Annu_Verma', 'Prashant_Tiwari', 'Trisha_Singh', 'SUBHAKANTA_RATH', 'Gulshan_Kumar', 'AMAN_Singh', 'Shivansh_Singh', 'abhinav_mishra', 'Ishika_Tiwari', 'Ayush_Jaiswal', 'RITIKA_CHAURASIYA', 'Love_Srivastava', 'Anushka_Mishra', 'Sanyam_Saxena', 'Vaishnavi_Gupta', 'Vishnu_Mandloi', 'Vivek_Singh', 'Vaibhav_Singh', 'Deepali_Raje', 'Muskan_Singh', 'Yashvardhan_Mishra', 'Priyanshu_Dubey', 'Harshit_Gupta', 'Himanshu_Mishra', 'Shagun_Jaiswal', 'Shilpi_Gupta', 'Kartikey_Sahu', 'Neha_Yadav', 'Divyansh_Agrawal', 'RAM SHANKAR_CHAUHAN', 'Bappy_Mallick', 'Hardik_Sahu', 'Shivendra_Tiwari', 'Pragati_Sharma', 'Saksham_Srivastava', 'Shivansh_Singh', 'Suryansh_Singh', 'Nikhil_Sharma', 'Ankita_Verma', 'Divyet_Agarwal', 'Shreyansh_Srivastava', 'Prashant_Singh', 'Noma_Khan', 'Girraj_Vaishnav', 'Shambhavi_Jaiswal', 'Harleen_Kaur', 'Pranjal_Sharma', 'Aditya_Maddhesiya', 'Aman_Singh', 'Dewansh_Gupta', 'Ravi_Rao', 'Mr. Prakhar_Raj', 'Muskan_Mishra', 'Sumit_Kumar', 'Muskan_Singh', 'Dipanshu_Jha', 'Amisha_Rawat', 'Devansh_Sharma', 'MANSI_YADAV', 'Priyanshu_Dixit', 'Israr_Ahmed', 'nan_nan', 'Vivekanand_Gurjar', 'Saksham_Shri Gupta', 'Abhay_Gupta', 'Kishlay_Kanaujia', 'Soni_Kumari', 'Ritanshu_Sharma', 'Shatakchi_Gupta', 'GARIMA_YADAV', 'Tehreem_.', 'nan_nan', 'SHIPRA_SINGH', 'Akanksha_Kushwaha', 'Vanshika_Das', 'Hitendra Kumar_Dewangan', 'Abhishek_Kumar', 'Purva_Singh', 'Mudit_Srivastava', 'shivangi_srivastav', 'sanchit_mishra', 'Raj_Prajapati', 'Shankho Subhra_Pal', 'Akhil Kumar_Sharma', 'Rochak_Gupta', 'Ayush_Tiwari', 'Nitin_Baghel', 'Mihir_Dixit', 'Rajneesh_Sharma', 'Rayna_Maheshwari', 'Neelmani_Rao', 'Kumar_Buddavarapu', 'Tanmay_Srivastava', 'Abhishek_Gupta', 'Abhishek_Tripathi', 'Aradhya_Sinha', 'Aashutosh_Yadav', 'Animesh_Singh', 'Aditya_Singh', 'Vansh_Rathour', 'Abhishek_Kumar', 'Saloni_Chauhan', 'Vansh_Goel', 'Aradhya_Tiwari', 'Sabiya_Ansari', 'Ananth_Sankar', 'Veer_Saxena', 'Jyoti_kumari', 'Amaan_Beg', 'Jitendra_Dhakad', 'Arjit_Kamboj', 'Shashank_Mishra', 'Hriddhi_Srivastava', 'Salik ram_Sahu', 'ASMIT_BIRTHARE', 'Akshat_Agarwal', 'Aryan_Kadwey', 'Eshika_Mishra', 'Ankur_Pathak', 'Manjari_Verma', 'vinod kumar_yadav', 'Shivangi_Prajapati', 'Vanshika_Joshi', 'AYUSH_CHAURASIYA', 'Vibhu_Pandey', 'Pragya_Sharma', 'Malavika_kumari', 'Sandhya_Kumari', 'Niraj_Prasad', 'Ritik kumar_Pandey', 'Samriddhi_Tiwari', 'Madhu_Kushwaha', 'Preeti_Sharma', 'Yash_Raj', 'Vachaspati_Pathak', 'Aryan_Shukla', 'Ayush_Mishra', 'Shubhi_Upadhyay', 'Rishabh_Srivastava', 'Garima_Tiwari', 'Zainab_Asma', 'Pratibha_singh', 'Harshita_Baggi', 'Nishant_Koundal', 'Ahad_Salim', 'Srishti_Singh', 'Pranshu_Agrahari', 'Niharika_Patel', 'Ramendra_Kumar', 'Ashutosh_Dubey', 'PREETI_SILODIYA', 'Yuvraj_Singh Lamba', 'Anshika_Singh', 'Anchal_Mishra', 'Shreya_Yadav', 'Garv_Rawal', 'Divya_Chandra Srivastava', 'Ankit_Gautam', 'Shrishti_Agrawal', 'KHUSHI_AGARWAL', 'Shipra_Verma', 'Nawed_Ashraf', 'Ayush_Verma', 'Saurabh_Singh', 'Shalini_Priya', 'Pratibha_Chaudhary', 'Satvik_Tripathi', 'Yash_Yadav', 'Rupa_Yadav', 'Ardhendu Bhushan_Mishra', 'Shakshi_Patel', 'Gaurav_Kumar', 'Aditya_Kumar', 'Shritika_Srivastava', 'Anshika_Saini', 'Bhagwan_singh', 'Pawan_Kumar', 'Ritesh Kumar_Yadav', 'Ritik_Singh', 'S ...
# Graph connections exported to D:\MFC PROJECT\adjacency_list.json
# Rohit_Malviya : 4650
# Connections : 4305
# Ramraj_Nagar : 3925
# Nirmal LinkdIn Connections : 3770
# Pranjal_Dubey : 3553
# Challa_Trivedh_Kumar : 3012
# Himanshu_kumar : 2919
# Neeraj_Parmar : 2811
# Aman_Singh : 2780
# ByagariPraveen_Kumar : 2639
# Janu_Chaudhary : 2262
# Ujjval_Baijal : 2252
# Prabhat_Patidar : 2179
# Alok_raj : 2134
# Rajiv_Kumar : 2046
# CHANDAN_GIRI : 2033
# Shubham Kumar : 1888
# Ayush_Kumar : 1765
# aryan_saini : 1663
# Shivang_Dubey : 1569
# Shubham_Kang : 1530
# Shivam_Shukla_csv : 1483
# Mayank_Raj : 1446
# Mohit_Sharma : 1318
# Manish_Tiwari : 1308
# Ishant_Bhoyar : 1043
# Ranjeet_Kumar_Yadav : 938
# Monu_Rajpoot : 909
# Prachi_Dhakad : 896
# Ekta Kumari : 859
# Mehtab_Alam : 824
# Bhaskar_mahato : 817
# Vivek_kumar : 806
# Connection : 797
# Priyadarshi_Kumar : 766
# Anand_Pandey : 756
# Anuradha_Tiwari : 742
# Nikhil_Chaurasiya : 737
# Pawan_Kushwah : 721
# Divyanshi_Sahu_csv : 698
# Harisingh_Rajpoot : 684
# JAMAL_AKHTAR : 682
# Shilpi_Shaw : 675
# Vinay_Kumar : 649
# debangsu_misra_csv : 628
# Suyash_Yadav : 621
# Gaurav_Tiwari : 604
# Afzal_Raza : 602
# Rahul_Kumar_Verma : 590
# Anshu_Kumar : 589
# Ajay Jatav Connections-1 : 580
# Sarthaksuman_Mishra : 504
# Swati_Kumari : 504
# Himanshu_Srivastav : 475
# Kuldeep_Saraswat : 472
# Vivek_Singh : 466
# Divyanshi_Rathour : 455
# Pushpraj_Singh_csv : 430
# Anushri_Mishra : 429
# amit_kumar : 425
# Pragati_Chauhan : 424
# Disha_Sahu : 415
# Priya_saini : 410
# Linked_in_connection : 402
# Samina_Sultana_csv : 402
# Prerana_Rajnag : 396
# Vishal_Bhardwaj : 390
# Sandhya_Parmar : 387
# Pinky_Rana : 370
# Akanksha_Kushwaha : 361
# Uppara Sai_Maithreyi : 354
# Bhagwati_Chouhan : 338
# Sandhya_Kaushal : 337
# Sunny_Kumar : 337
# Dilip_Suthar : 336
# Hiranya_Patil : 320
# Lakhan_Rathore : 319
# Vinay_Gupta : 312
# Aman_ Adarsh_csv : 301
# Rani_Kumari : 301
# Arjun Kadam : 300
# Mohd_Monis : 293
# Sauhard_kumar : 292
# Aditya_Singh : 291
# linkedin list : 272
# Arpita_Tripathi : 270
# khushi_narwariya : 269
# Aaditya_Raj : 267
# Satish_Mahto : 238
# Anoop_Kumar : 237
# Saurabh_Bisht : 229
# Ayush_yadav : 222
# Rohit_kumar : 212
# Mausam_kumari : 206
# Sandeep_kumar : 201
# Shahid_Ansari : 200
# Rahul_Kumar : 186
# Sajan_Kumar : 181
# Ajit_Yadav : 179
# YuvrajSingh_Bhati : 175
# Abhishek_Singh : 164
# gaurav_khainwar_csv : 159
# Ravi_Mourya : 155
# Naman_Damami : 142
# Ritik_Singh : 128
# Cleaned_Connections : 123
# KARANPAL_SINGH_RANAWAT : 114
# Maneesh_Sakhwar : 99
# Chiranjeet_Biswas : 84

# %%
# Write a code to inter-convert the 3 graph representations we have learnt.

def adjlist_to_edgelist(adjbook):
    edge_storage = set()
    for region in adjbook:
        for neighbor, weight in adjbook[region]:
            link = tuple(sorted([region, neighbor]) + [weight])
            edge_storage.add(link)
    return list(edge_storage)

def edgelist_to_adjlist(linktable):
    adjbook = {}
    for src, tgt, cost in linktable:
        adjbook.setdefault(src, []).append((tgt, cost))
        adjbook.setdefault(tgt, []).append((src, cost))
    return adjbook

def adjlist_to_adjmatrix(adjbook):
    nodes = sorted(adjbook.keys())
    node_index = {node: idx for idx, node in enumerate(nodes)}

    size = len(nodes)
    matrix = [["__" for _ in range(size)] for _ in range(size)]

    for point, links in adjbook.items():
        for buddy, distance in links:
            i = node_index[point]
            j = node_index[buddy]
            matrix[i][j] = distance
            matrix[j][i] = distance

    return nodes, matrix

def adjmatrix_to_adjlist(matdata):
    nodenames = matdata[0][1:]
    adjbook = {node: [] for node in nodenames}

    for i in range(1, len(matdata)):
        for j in range(1, len(matdata)):
            if matdata[i][j] != "__" and i != j:
                adjbook[matdata[i][0]].append((matdata[0][j], matdata[i][j]))
    return adjbook

def edgelist_to_adjmatrix(linktable):
    adjbook = edgelist_to_adjlist(linktable)
    return adjlist_to_adjmatrix(adjbook)

def adjmatrix_to_edgelist(matdata):
    nodenames = matdata[0][1:]
    edge_storage = set()

    for i in range(1, len(matdata)):
        for j in range(i + 1, len(matdata)):
            if matdata[i][j] != "__":
                link = tuple(sorted([nodenames[i-1], nodenames[j-1]]) + [matdata[i][j]])
                edge_storage.add(link)
    return list(edge_storage)

# %%
# Given a graph and two vertices, check if they are adjacent. 

def is_neighbor(chart, node1, node2):
    if isinstance(chart, list):
        first_part = chart[0]
        if isinstance(first_part, list):
            names = chart[0][1:]
            try:
                pos1 = names.index(node1) + 1
                pos2 = names.index(node2) + 1
            except ValueError:
                return False
            return chart[pos1][pos2] != "__"
        
        elif isinstance(first_part, tuple):
            structure = edgelist_to_adjlist(chart)
            return any(adj == node2 for adj, _ in structure.get(node1, []))
        
        else:
            raise ValueError("Unsupported graph format in list")
    
    elif isinstance(chart, dict):
        return any(adj == node2 for adj, _ in chart.get(node1, []))
    
    else:
        raise ValueError("Graph input format not recognized")

# %%
# Check if a graph is complete.

def verify_complete(netgraph):
    if isinstance(netgraph, list):
        begin_piece = netgraph[0]
        if isinstance(begin_piece, list):
            table = netgraph
        elif isinstance(begin_piece, tuple):
            table = edgelist_to_adjmatrix(netgraph)
        else:
            raise ValueError("Invalid list structure detected")
    
    elif isinstance(netgraph, dict):
        table = adjlist_to_adjmatrix(netgraph)
    
    else:
        raise ValueError("Graph input type not acceptable")
    
    total_nodes = len(table) - 1
    active_edges = 0

    for r in range(1, len(table)):
        for c in range(r + 1, len(table)):
            if table[r][c] != "__":
                active_edges += 1

    required_edges = (total_nodes * (total_nodes - 1)) // 2
    return active_edges == required_edges

# %%
# Check if a graph is connected.

def verify_linkage(graphinfo):
    if isinstance(graphinfo, list):
        primary_block = graphinfo[0]
        if isinstance(primary_block, list):
            neighbor_map = adjmatrix_to_adjlist(graphinfo)
        elif isinstance(primary_block, tuple):
            neighbor_map = edgelist_to_adjlist(graphinfo)
        else:
            raise ValueError("Unsupported list structure detected")
    
    elif isinstance(graphinfo, dict):
        neighbor_map = graphinfo

    else:
        raise ValueError("Unsupported graph input type")
    
    if not neighbor_map:
        return False
    
    points = list(neighbor_map.keys())
    if not points:
        return False

    explored = set()

    def explore(node):
        explored.add(node)
        for friend, _ in neighbor_map[node]:
            if friend not in explored:
                explore(friend)

    origin = points[0]
    explore(origin)

    return len(explored) == len(points)

# %%
# Given a graph and a list of vertices, check if it forms a walk, or a trail or a path or none of these.

def evaluate_sequence(network, junctions):
    if isinstance(network, list):
        top_layer = network[0]
        if isinstance(top_layer, list):
            connection_map = adjmatrix_to_adjlist(network)
        elif isinstance(top_layer, tuple):
            connection_map = edgelist_to_adjlist(network)
        else:
            raise ValueError("Invalid list-based graph detected")
    
    elif isinstance(network, dict):
        connection_map = network
    
    else:
        raise ValueError("Graph input format not recognized")
    
    if len(junctions) <= 1:
        return "walk"
    
    for point in junctions:
        if point not in connection_map:
            return "none"
    
    for idx in range(len(junctions) - 1):
        curr_node = junctions[idx]
        next_node = junctions[idx + 1]
        linked = [dest for dest, _ in connection_map[curr_node]]
        if next_node not in linked:
            return "none"
    
    link_memory = set()
    for idx in range(len(junctions) - 1):
        start = junctions[idx]
        end = junctions[idx + 1]
        bond = frozenset([start, end])
        if bond in link_memory:
            return "walk"
        link_memory.add(bond)
    
    if len(set(junctions)) < len(junctions):
        return "trail"
    
    return "path"

# %%
# Check if a given graph is a tree.

def validate_tree(graph_content):
    if isinstance(graph_content, list):
        upper_part = graph_content[0]
        if isinstance(upper_part, list):
            mapping = adjmatrix_to_adjlist(graph_content)
        elif isinstance(upper_part, tuple):
            mapping = edgelist_to_adjlist(graph_content)
        else:
            raise ValueError("Unsupported graph structure")
    
    elif isinstance(graph_content, dict):
        mapping = graph_content
    
    else:
        raise ValueError("Invalid graph input detected")
    
    if not mapping:
        return False

    hubs = list(mapping.keys())
    if not hubs:
        return False

    visited_nodes = set()

    def explore(curr_node, prior_node=None):
        visited_nodes.add(curr_node)
        for adjacent, _ in mapping[curr_node]:
            if adjacent == prior_node:
                continue
            if adjacent in visited_nodes:
                return False
            if not explore(adjacent, curr_node):
                return False
        return True

    kickoff = hubs[0]
    tree_status = explore(kickoff)
    return tree_status and len(visited_nodes) == len(hubs)

# %%
# Given a connected cyclic graph, find its spanning tree.

def extract_spanning_tree(graph_data):
    if isinstance(graph_data, list):
        primary_section = graph_data[0]
        if isinstance(primary_section, list):
            edge_details = adjmatrix_to_edgelist(graph_data)
        elif isinstance(primary_section, tuple):
            edge_details = graph_data
        else:
            raise ValueError("Invalid graph data structure")
    
    elif isinstance(graph_data, dict):
        edge_details = adjlist_to_edgelist(graph_data)
    
    else:
        raise ValueError("Graph input format not recognized")
    
    edge_details.sort(key=lambda x: x[2])

    parent_nodes = {}
    tree_ranks = {}

    def init_set(vertex):
        if vertex not in parent_nodes:
            parent_nodes[vertex] = vertex
            tree_ranks[vertex] = 0

    def find_parent(vertex):
        if parent_nodes[vertex] != vertex:
            parent_nodes[vertex] = find_parent(parent_nodes[vertex])
        return parent_nodes[vertex]

    def union_nodes(vertex1, vertex2):
        root1 = find_parent(vertex1)
        root2 = find_parent(vertex2)
        
        if root1 != root2:
            if tree_ranks[root1] < tree_ranks[root2]:
                root1, root2 = root2, root1
            parent_nodes[root2] = root1
            if tree_ranks[root1] == tree_ranks[root2]:
                tree_ranks[root1] += 1
            return True
        return False

    unique_vertices = set()
    for source, destination, _ in edge_details:
        unique_vertices.add(source)
        unique_vertices.add(destination)
        init_set(source)
        init_set(destination)

    spanning_tree_edges = []
    for source, destination, weight in edge_details:
        if union_nodes(source, destination):
            spanning_tree_edges.append((source, destination, weight))

    spanning_tree = {}
    for source, destination, weight in spanning_tree_edges:
        if source not in spanning_tree:
            spanning_tree[source] = []
        if destination not in spanning_tree:
            spanning_tree[destination] = []
        spanning_tree[source].append((destination, weight))
        spanning_tree[destination].append((source, weight))

    return spanning_tree

# %%
# Given a tree, find the number of leaf nodes.
from typing import Dict, List
def count_leaves(tree: Dict[str,List[str]]) -> int:
    # all nodes = keys ∪ all children
    all_nodes = set(tree.keys()) | {c for children in tree.values() for c in children}
    count = 0
    for node in all_nodes:
        # if node not a key or has empty children
        if not tree.get(node):
            count += 1
    return count

# %%
# Given a tree, check if it's a binary tree.
from typing import Dict, List
def is_binary_tree(tree: Dict[str,List[str]]) -> bool:
    all_nodes = set(tree.keys()) | {c for children in tree.values() for c in children}
    for node in all_nodes:
        if len(tree.get(node, [])) > 2:
            return False
    return True

# %%
# Given a tree, find its height.

def tree_height(tree: Dict[str,List[str]]) -> int:
    # identify root = all_nodes − children
    all_nodes = set(tree.keys()) | {c for children in tree.values() for c in children}
    children_set = {c for children in tree.values() for c in children}
    roots = list(all_nodes - children_set)
    if len(roots) != 1:
        raise ValueError("Tree must have exactly one root")
    root = roots[0]

    def height(u):
        kids = tree.get(u, [])
        if not kids:
            return 0
        return 1 + max(height(c) for c in kids)

    return height(root)

# %%
# Given a tree, find its depth.
from collections import deque

def node_depths(tree: Dict[str,List[str]]) -> Dict[str,int]:
    all_nodes = set(tree.keys()) | {c for children in tree.values() for c in children}
    children_set = {c for children in tree.values() for c in children}
    roots = list(all_nodes - children_set)
    if len(roots) != 1:
        raise ValueError("Tree must have exactly one root")
    root = roots[0]

    depth = {root: 0}
    q = deque([root])
    while q:
        u = q.popleft()
        for c in tree.get(u, []):
            depth[c] = depth[u] + 1
            q.append(c)
    return depth
